# %% [markdown]
# <a href="https://colab.research.google.com/github/satani99/hello_world_of_ml/blob/main/working_with_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m pip install --user requests

# %%
import requests

url = "https://api.github.com/search/repositories?q=language:python&sort=stars"
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

response_dict = r.json()

print(response_dict.keys())
# Out:
# Status code: 200
# dict_keys(['total_count', 'incomplete_results', 'items'])

# %%
print(f"Total repositories: {response_dict['total_count']}")

repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")

repo_dict = repo_dicts[0]
print(f"\nKeys: {len(repo_dict)}")
for key in sorted(repo_dict.keys()):
  print(key)
# Out:
# Total repositories: 9292472
# Repositories returned: 30
#
# Keys: 80
# allow_forking
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_discussions
# has_downloads
# has_issues
# has_pages
# has_projects
# has_wiki
# homepage
# hooks_url
# html_url
# id
# is_template
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pulls_url
# pushed_at
# releases_url
# score
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# ...

# %%
print("\nSelected information about first repository:")
for repo_dict in repo_dicts:
  print(f"Name: {repo_dict['name']}")
  print(f"Owner: {repo_dict['owner']['login']}")
  print(f"Stars: {repo_dict['stargazers_count']}")
  print(f"Repository: {repo_dict['html_url']}")
  print(f"Created: {repo_dict['created_at']}")
  print(f"Updated: {repo_dict['updated_at']}")
  print(f"Description: {repo_dict['description']}")
# Out:
# Selected information about first repository:
# Name: ssh-audit
# Owner: arthepsy
# Stars: 2885
# Repository: https://github.com/arthepsy/ssh-audit
# Created: 2015-12-23T02:54:38Z
# Updated: 2023-08-13T03:55:14Z
# Description: SSH server auditing (banner, key exchange, encryption, mac, compression, compatibility, security, etc)
# Name: NakedTensor
# Owner: jostmey
# Stars: 2429
# Repository: https://github.com/jostmey/NakedTensor
# Created: 2016-09-08T16:49:07Z
# Updated: 2023-08-15T10:54:48Z
# Description: Bare bone examples of machine learning in TensorFlow
# Name: vincent
# Owner: wrobstory
# Stars: 2045
# Repository: https://github.com/wrobstory/vincent
# Created: 2013-04-11T02:44:53Z
# Updated: 2023-07-21T00:39:14Z
# Description: A Python to Vega translator
# Name: stethoscope
# Owner: Netflix-Skunkworks
# Stars: 2000
# Repository: https://github.com/Netflix-Skunkworks/stethoscope
# Created: 2017-01-09T21:39:48Z
# Updated: 2023-08-12T13:43:21Z
# ...

# %%
from operator import itemgetter

import requests

url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
r = requests.get(url)
print(f"Status code: {r.status_code}")

submission_ids = r.json()
submission_dicts = []
for submission_id in submission_ids[:30]:
  url = f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
  r = requests.get(url)
  print(f"id: {submission_id}\tstatus: {r.status_code}")
  response_dict = r.json()

  submission_dict = {
      'title': response_dict['title'],
      'hn_link': f"http://news.ycombinator.com/item?id={submission_id}",
      'comments': response_dict['descendants'],
  }
  submission_dicts.append(submission_dict)
# Out:
# Status code: 200
# id: 37224042	status: 200
# id: 37227139	status: 200
# id: 37230843	status: 200
# id: 37230619	status: 200
# id: 37220953	status: 200
# id: 37227229	status: 200
# id: 37223995	status: 200
# id: 37228822	status: 200
# id: 37224651	status: 200
# id: 37229030	status: 200
# id: 37217757	status: 200
# id: 37229212	status: 200
# id: 37215374	status: 200
# id: 37226360	status: 200
# id: 37229403	status: 200
# id: 37221576	status: 200
# id: 37222571	status: 200
# id: 37228166	status: 200
# id: 37229689	status: 200
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-6b94790c4c94> in <cell line: 11>()
#      18       'title': response_dict['title'],
#      19       'hn_link': f"http://news.ycombinator.com/item?id={submission_id}",
# ---> 20       'comments': response_dict['descendants'],
#      21   }
#      22   submission_dicts.append(submission_dict)
# ...

# %%
submission_dicts = sorted(submission_dicts, key=itemgetter('comments'),
                          reverse=True)

for submission_dict in submission_dicts:
  print(f"\nTitle: {submission_dict['title']}")
  print(f"Discussion link: {submission_dict['hn_link']}")
  print(f"Comments: {submission_dict['comments']}")
# Out:
# Title: The first conformant M1 GPU driver
# Discussion link: http://news.ycombinator.com/item?id=37224042
# Comments: 494
#
# Title: The new science of meditation
# Discussion link: http://news.ycombinator.com/item?id=37222571
# Comments: 290
#
# Title: GPT-3.5 Turbo fine-tuning and API updates
# Discussion link: http://news.ycombinator.com/item?id=37227139
# Comments: 175
#
# Title: I only lost 10 minutes of data, thanks to ZFS
# Discussion link: http://news.ycombinator.com/item?id=37230619
# Comments: 126
#
# Title: Structured logging with slog
# Discussion link: http://news.ycombinator.com/item?id=37224651
# Comments: 108
#
# Title: Your brain on emoji
# Discussion link: http://news.ycombinator.com/item?id=37228166
# Comments: 75
#
# Title: Eye scans detect signs of Parkinson’s disease up to seven years before diagnosis
# Discussion link: http://news.ycombinator.com/item?id=37230843
# Comments: 63
#
# Title: How to Solve It (1945)
# ...
